# %%
import os
import pandas as pd

# %%
df = pd.read_csv("winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1596 entries, 0 to 1595
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1596 non-null   float64
#  1   volatile acidity      1596 non-null   float64
#  2   citric acid           1596 non-null   float64
#  3   residual sugar        1596 non-null   float64
#  4   chlorides             1596 non-null   float64
#  5   free sulfur dioxide   1596 non-null   float64
#  6   total sulfur dioxide  1596 non-null   float64
#  7   density               1596 non-null   float64
#  8   pH                    1596 non-null   float64
#  9   sulphates             1596 non-null   float64
#  10  alcohol               1596 non-null   float64
#  11  quality               1596 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 149.8 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 239

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1596.000000       1596.000000  1596.000000     1596.000000
# mean        8.314160          0.527954     0.270276        2.535558
# std         1.732203          0.179176     0.193894        1.405515
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.600000          1.580000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1596.000000          1596.000000           1596.000000  1596.000000
# mean      0.087120            15.858396             46.382206     0.996744
# std       0.045251            10.460554             32.839138     0.001888
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your pandas DataFrame containing the dataset

# Numeric Columns
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Categorical Columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Univariate Analysis - Numeric Columns (Histograms)
for col in numeric_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Univariate Analysis - Categorical Columns (Countplots)
for col in categorical_columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=col)
    plt.title(f'Count of categories in {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Bivariate Analysis - Numeric vs Numeric (Scatter Plot and Correlation)
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='alcohol', y='quality')
plt.title('Scatter plot of alcohol content vs quality')
plt.xlabel('Alcohol content')
plt.ylabel('Quality')
plt.show()

# Correlation Matrix for Numerical Variables
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# Bivariate Analysis - Categorical vs Numeric (Box Plot)
plt.figure(figsize=(10, 8))
sns.boxplot(data=df, x='quality', y='alcohol')
plt.title('Box plot of alcohol content across quality levels')
plt.xlabel('Quality')
plt.ylabel('Alcohol content')
plt.show()

# Bivariate Analysis - Categorical vs Categorical (Heatmap)
plt.figure(figsize=(10, 8))
pivot = df.groupby(['quality']).size().reset_index().pivot(columns='quality', values=0)
sns.heatmap(pivot, annot=True, cmap='Blues', linewidths=0.5)
plt.title('Heatmap of wine quality by color')
plt.xlabel('Quality')
plt.ylabel('Color')
plt.show()

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1596.000000       1596.000000  1596.000000     1596.000000
# mean        8.314160          0.527954     0.270276        2.535558
# std         1.732203          0.179176     0.193894        1.405515
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.600000          1.580000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1596.000000          1596.000000           1596.000000  1596.000000
# mean      0.087120            15.858396             46.382206     0.996744
# std       0.045251            10.460554             32.839138     0.001888
# ...

# %%
import matplotlib.pyplot as plt
df.hist(bins = 50,figsize=(20,14),color = "blue")
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
from  sklearn.preprocessing import StandardScaler

# %%
x =df.drop(["quality"],axis=1,inplace =False)
y = df.quality

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1591    5
# 1592    6
# 1593    6
# 1594    5
# 1595    6
# Name: quality, Length: 1596, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =.30,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (1117, 11)
# (479, 11)
# (479,)
# (1117,)

# %%
from sklearn.linear_model import ElasticNet
lr =ElasticNet(alpha= 0.1,l1_ratio=0.5,max_iter=1129,random_state=42)
lr.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.1, max_iter=1129, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, mean_squared_error, r2_score,mean_absolute_error
import numpy as np

# %%
def eval_metrics(actual,predicted):
    rmse = np.sqrt(mean_squared_error(actual,predicted))
    mae = mean_absolute_error(actual,predicted)
    r2 = r2_score(actual,predicted)

    return rmse,mae,r2

# %%
predict_value = lr.predict(x_test)
predict_value
# Out:
# array([5.6849811 , 5.99327466, 5.38106559, 5.65299682, 5.26313943,
#        5.47883817, 5.3599082 , 5.3963255 , 6.20227187, 5.47213452,
#        5.3402938 , 5.47729753, 5.72975963, 5.90086309, 5.44706952,
#        5.92355207, 5.33247496, 5.59114918, 6.11556775, 6.34207905,
#        5.49549994, 5.36200271, 6.25463298, 5.17459883, 6.62501294,
#        6.13157057, 5.93069518, 5.27852366, 5.74714061, 6.26903766,
#        5.43763291, 6.12825376, 5.33856019, 6.1587124 , 5.27367584,
#        5.20667789, 6.13056413, 5.92567998, 5.74588944, 5.34125886,
#        6.03604167, 5.14558976, 5.40688092, 5.22845064, 5.16887158,
#        5.43295257, 5.29933857, 5.61546443, 5.551241  , 6.05806007,
#        5.17119525, 5.6849811 , 5.84815192, 6.01754057, 5.29973802,
#        5.26885489, 5.36174335, 5.42483149, 5.70224665, 6.13284547,
#        5.83309349, 5.7499256 , 5.43248967, 5.30135652, 5.44436217,
#        5.41950369, 5.5335413 , 5.59651468, 6.08470906, 6.03608326,
# ...

# %%
(rmse,mae,r2) = eval_metrics(y_test,predict_value)
print("rmae \t ", rmse)
print("mae \t",mae)
print("r2 \t ", r2)
# Out:
# rmae 	  0.7022998272337306
# mae 	 0.5539226081174153
# r2 	  0.24049632157703005
